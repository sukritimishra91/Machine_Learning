# %%
##Loading dataset

# %%
from sklearn.datasets import fetch_california_housing
import os, ssl
if (not os.environ.get('PYTHONHTTPSVERIFY', '') and
    getattr(ssl, '_create_unverified_context', None)): 
    ssl._create_default_https_context = ssl._create_unverified_context
california = fetch_california_housing()

# %%
print(california.DESCR) #description of dataset
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# ...

# %%
housing = fetch_california_housing()   #importing important libraries for data visualization
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams
# %matplotlib inline

# %%
print(f'  Data shape = {california.data.shape}')
print(f'Target shape = {california.target.shape}')   # split the data into training and testing dataset
# Out:
#   Data shape = (20640, 8)
# Target shape = (20640,)

# %%
california   #california.feature_names
# Out:
# {'DESCR': '.. _california_housing_dataset:\n\nCalifornia Housing dataset\n--------------------------\n\n**Data Set Characteristics:**\n\n    :Number of Instances: 20640\n\n    :Number of Attributes: 8 numeric, predictive attributes and the target\n\n    :Attribute Information:\n        - MedInc        median income in block\n        - HouseAge      median house age in block\n        - AveRooms      average number of rooms\n        - AveBedrms     average number of bedrooms\n        - Population    block population\n        - AveOccup      average house occupancy\n        - Latitude      house block latitude\n        - Longitude     house block longitude\n\n    :Missing Attribute Values: None\n\nThis dataset was obtained from the StatLib repository.\nhttp://lib.stat.cmu.edu/datasets/\n\nThe target variable is the median house value for California districts.\n\nThis dataset was derived from the 1990 U.S. census, using one row per census\nblock group. A block group is the smallest geogr
# ...

# %%
import pandas as pd

california_df = pd.DataFrame(california.data, 
                             columns=california.feature_names)
california_df['MedHouseValue'] = pd.Series(california.target)

max(california_df['MedHouseValue'])       #exploring the data
# Out:
# 5.00001

# %%
pd.set_option('precision', 4)
pd.set_option('max_columns', 9)
pd.set_option('display.width', None)

california_df.head()    #exploration
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0    6.9841     1.0238       322.0    2.5556     37.88
# 1  8.3014      21.0    6.2381     0.9719      2401.0    2.1098     37.86
# 2  7.2574      52.0    8.2881     1.0734       496.0    2.8023     37.85
# 3  5.6431      52.0    5.8174     1.0731       558.0    2.5479     37.85
# 4  3.8462      52.0    6.2819     1.0811       565.0    2.1815     37.85
#
#    Longitude  MedHouseValue
# 0    -122.23          4.526
# 1    -122.22          3.585
# 2    -122.24          3.521
# 3    -122.25          3.413
# 4    -122.25          3.422

# %%
california_df.describe()
# Out:
#            MedInc    HouseAge    AveRooms   AveBedrms  Population    AveOccup  \
# count  20640.0000  20640.0000  20640.0000  20640.0000  20640.0000  20640.0000
# mean       3.8707     28.6395      5.4290      1.0967   1425.4767      3.0707
# std        1.8998     12.5856      2.4742      0.4739   1132.4621     10.3860
# min        0.4999      1.0000      0.8462      0.3333      3.0000      0.6923
# 25%        2.5634     18.0000      4.4407      1.0061    787.0000      2.4297
# 50%        3.5348     29.0000      5.2291      1.0488   1166.0000      2.8181
# 75%        4.7432     37.0000      6.0524      1.0995   1725.0000      3.2823
# max       15.0001     52.0000    141.9091     34.0667  35682.0000   1243.3333
#
#          Latitude   Longitude  MedHouseValue
# count  20640.0000  20640.0000     20640.0000
# mean      35.6319   -119.5697         2.0686
# std        2.1360      2.0035         1.1540
# min       32.5400   -124.3500         0.1500
# ...

# %%
### Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

sns.set(font_scale=2)
sns.set_style('whitegrid')

# %%
for feature in california.feature_names:
     plt.figure(figsize=(16, 9))
     sns.scatterplot(data=sample_df, x=feature, y='MedHouseValue', 
                     hue='MedHouseValue', 
                     palette='cool', legend=False)

# %%
### Histogram
import matplotlib.pyplot as plt
california_df.hist(bins=50, figsize=(20,15))
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %%
sample_df = california_df.sample(frac=0.2, random_state=17)  ### testing data is 20%

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = \
    train_test_split(california.data, california.target, random_state=11)

print(f'Shape of training set = {X_train.shape}')
print(f'Shape of testing  set = {X_test.shape}')
# Out:
# Shape of training set = (15480, 8)
# Shape of testing  set = (5160, 8)

# %%
california_df["income_cat"] = pd.cut(california_df["MedInc"],
                               bins=[0., 1.5, 3.0, 4.5, 6., np.inf],
                               labels=[1, 2, 3, 4, 5])

# %%
california_df["income_cat"].hist()

# %%
### Feature Scaling

# %%
strat_test_set["income_cat"].value_counts() / len(strat_test_set)
# Out:
# 3    0.3505
# 2    0.3188
# 4    0.1764
# 5    0.1146
# 1    0.0397
# Name: income_cat, dtype: float64

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(california_df, california_df["income_cat"]):
    strat_train_set = california_df.loc[train_index]
    strat_test_set = california_df.loc[test_index]

# %%
strat_test_set["income_cat"].value_counts() / len(strat_test_set)
# Out:
# 3    0.3505
# 2    0.3188
# 4    0.1764
# 5    0.1146
# 1    0.0397
# Name: income_cat, dtype: float64

# %%
for set_ in (strat_train_set, strat_test_set):
    set_.drop("income_cat", axis=1, inplace=True)

# %%
california_df = strat_train_set.copy()

# %%
california_df.plot(kind="scatter", x="Longitude", y="Latitude")
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
california_df.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.1)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
california_df.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.4,
    s=california_df["Population"]/100, label="Population", figsize=(10,7),
    c="MedHouseValue", cmap=plt.get_cmap("jet"), colorbar=True,
)
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %%
corr_matrix = california_df.corr()

# %%
corr_matrix["MedHouseValue"].sort_values(ascending=False)
# Out:
# MedHouseValue    1.0000
# MedInc           0.6872
# AveRooms         0.1463
# HouseAge         0.1141
# AveOccup        -0.0220
# Population      -0.0269
# AveBedrms       -0.0433
# Longitude       -0.0474
# Latitude        -0.1427
# Name: MedHouseValue, dtype: float64

# %%
from pandas.plotting import scatter_matrix

attributes = ["MedHouseValue", "MedInc", "AveRooms","HouseAge"]
scatter_matrix(california_df[attributes], figsize=(12, 8))
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %%
california_df.plot(kind="scatter", x="MedInc", y="MedHouseValue",
             alpha=0.1)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
### Train the model

# %%
from sklearn.linear_model import LinearRegression

linear_regression = LinearRegression()
linear_regression.fit(X=X_train, y=y_train)

for i, name in enumerate(california.feature_names):
    print(f'{name:>11}: {linear_regression.coef_[i]:24.20f}')

print()
print(f'y-intercept: {linear_regression.intercept_:23.20f}')
# Out:
#      MedInc:   0.43770302153822060465
#    HouseAge:   0.00921683456579774907
#    AveRooms:  -0.10732526637360925714
#   AveBedrms:   0.61171330739180873604
#  Population:  -0.00000575682200927574
#    AveOccup:  -0.00338456646571644185
#    Latitude:  -0.41948186096490669428
#   Longitude:  -0.43377133498740227946
#
# y-intercept: -36.88295065605559841515

# %%
california_df = strat_train_set.drop("MedHouseValue", axis=1)
housing_labels = strat_train_set["MedHouseValue"].copy()

# %%
california_df.dropna(subset=["AveBedrms"])    # option 1
california_df.drop("AveBedrms", axis=1)       # option 2
median = california_df["AveBedrms"].median()  # option 3
california_df["AveBedrms"].fillna(median, inplace=True)

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="median")

# %%
housing_num = california_df

# %%
imputer.fit(housing_num)
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='median', verbose=0)

# %%
imputer.statistics_
# Out:
# array([ 3.54090000e+00,  2.90000000e+01,  5.23228423e+00,  1.04861111e+00,
#         1.16400000e+03,  2.81765270e+00,  3.42600000e+01, -1.18510000e+02])

# %%
housing_num.median().values
# Out:
# array([ 3.54090000e+00,  2.90000000e+01,  5.23228423e+00,  1.04861111e+00,
#         1.16400000e+03,  2.81765270e+00,  3.42600000e+01, -1.18510000e+02])

# %%
X = imputer.transform(housing_num)

# %%
housing_tr = pd.DataFrame(X, columns=housing_num.columns)

# %%
housing_cat = california_df
housing_cat.head(10)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 17606  2.7042      38.0    4.6254     1.0354       710.0    2.0944     37.29
# 18632  6.4214      14.0    6.0088     0.9558       306.0    2.7080     37.05
# 14650  2.8621      31.0    4.2251     1.0195       936.0    2.0260     32.77
# 3230   1.8839      25.0    5.2323     1.0510      1460.0    4.1360     36.31
# 3555   3.0347      17.0    4.5058     1.0424      4459.0    3.0478     34.23
# 19480  3.5395      24.0    5.1404     1.0316      1448.0    2.5404     37.66
# 8879   8.3839      52.0    8.0614     1.1444       769.0    2.7762     34.04
# 13685  6.0000      26.0    5.4427     0.7813       936.0    2.4960     34.15
# 4937   1.8242      47.0    4.2580     1.0616      1916.0    4.3744     33.99
# 4861   0.4999      29.0    2.3733     1.0553      2690.0   12.3963     34.02
#
#        Longitude
# 17606    -121.89
# 18632    -121.93
# 14650    -117.20
# 3230     -119.61
# 3555     -118.59
# ...

# %%
from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

num_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy="median")),
        ('attribs_adder', CombinedAttributesAdder()),
        ('std_scaler', StandardScaler()),
    ])

housing_num_tr = num_pipeline.fit_transform(housing_num)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

num_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy="median")),
        ('attribs_adder', CombinedAttributesAdder()),
        ('std_scaler', StandardScaler()),
    ])

housing_num_tr = num_pipeline.fit_transform(housing_num)

# %%
housing_prepared = full_pipeline.fit_transform(california_df)

# %%
###Test the model

# %%
import math
from sklearn import metrics

predicted = linear_regression.predict(X_test)
expected  = y_test

r2 = metrics.r2_score(expected, predicted)
r  = math.sqrt(r2)

print(f'coefficient of determination = {r2:.1f}')
print(f'     correlation coefficient = {r:.1f}')
# Out:
# coefficient of determination = 0.6
#      correlation coefficient = 0.8

# %%
df = pd.DataFrame()

df['Expected']  = pd.Series(expected)
df['Predicted'] = pd.Series(predicted)

figure = plt.figure(figsize=(15, 10))

axes = sns.scatterplot(data=df, x='Expected', y='Predicted', 
                       hue='Predicted', palette='cool', 
                       legend=False)

start = min(expected.min(), predicted.min())
end   = max(expected.max(), predicted.max())

axes.set_xlim(start, end)
axes.set_ylim(start, end)

line = plt.plot([start, end], [start, end], 'k--')

# %%
### Implementation Of Linear regression model

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(housing_prepared, housing_labels)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
some_data = california_df.iloc[:5]
some_labels = housing_labels.iloc[:5]
some_data_prepared = full_pipeline.transform(some_data)
print("Predictions:", lin_reg.predict(some_data_prepared))
print("Labels:", list(some_labels))
# Out:
# Predictions: [2.01914287 3.32067796 1.89953206 0.87340085 1.7569142 ]
# Labels: [2.866, 3.406, 1.969, 0.463, 2.545]

# %%
### Calculating the root mean squared error value

# %%
from sklearn.metrics import mean_squared_error
housing_predictions = lin_reg.predict(housing_prepared)
lin_mse = mean_squared_error(housing_labels, housing_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 0.7218655050857536

# %%
### Implementation of Decision Tree Regressor ML model

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor()
tree_reg.fit(housing_prepared, housing_labels)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
housing_predictions = tree_reg.predict(housing_prepared)
tree_mse = mean_squared_error(housing_labels, housing_predictions)
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# 2.3826388682894208e-07

# %%
### Cross-Validation

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(tree_reg, housing_prepared, housing_labels,
                         scoring="neg_mean_squared_error", cv=10)
tree_rmse_scores = np.sqrt(-scores)

# %%
def display_scores(scores):
...     print("Scores:", scores)
...     print("Mean:", scores.mean())
...     print("Standard deviation:", scores.std())
display_scores(tree_rmse_scores)
# Out:
# Scores: [0.71862292 0.71731912 0.73592321 0.76691124 0.72885163 0.76264827
#  0.72585365 0.69108234 0.70908123 0.73852664]
# Mean: 0.7294820257355485
# Standard deviation: 0.021896089008906258

# %%
lin_scores = cross_val_score(lin_reg, housing_prepared, housing_labels,
...                              scoring="neg_mean_squared_error", cv=10)
...
>>> lin_rmse_scores = np.sqrt(-lin_scores)
>>> display_scores(lin_rmse_scores)
# Out:
# Scores: [0.69855891 0.79758958 0.72168752 0.72613355 0.74186247 0.74133331
#  0.68380679 0.72937078 0.7712556  0.71405535]
# Mean: 0.7325653862276177
# Standard deviation: 0.03151944820674264

# %%
from sklearn.ensemble import RandomForestRegressor
forest_reg = RandomForestRegressor()
forest_reg.fit(housing_prepared, housing_labels)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
forest_rmse
# Out:
# array([-0.48798455, -0.63614914, -0.52083287, -0.52726993, -0.55035993,
#        -0.54957508, -0.46759172, -0.53198174, -0.5948352 , -0.50987505])

# %%
### To increase the accuracy of the model implementation of Grid search CV

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
    {'n_estimators': [3, 10, 30], 'max_features': [2, 4, 6, 8]},
    {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]},
  ]

forest_reg = RandomForestRegressor()

grid_search = GridSearchCV(forest_reg, param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           return_train_score=True)

grid_search.fit(housing_prepared, housing_labels)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
# ...

# %%
grid_search.best_params_
# Out:
# {'max_features': 4, 'n_estimators': 30}

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features=4, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=30, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
  print(np.sqrt(-mean_score), params)
# Out:
# 0.6455309291636209 {'max_features': 2, 'n_estimators': 3}
# 0.5688175441546248 {'max_features': 2, 'n_estimators': 10}
# 0.5338477014307931 {'max_features': 2, 'n_estimators': 30}
# 0.6205732301142933 {'max_features': 4, 'n_estimators': 3}
# 0.5417034770596992 {'max_features': 4, 'n_estimators': 10}
# 0.5143158755556861 {'max_features': 4, 'n_estimators': 30}
# 0.6113533266781993 {'max_features': 6, 'n_estimators': 3}
# 0.5444586041772064 {'max_features': 6, 'n_estimators': 10}
# 0.5196486996105382 {'max_features': 6, 'n_estimators': 30}
# 0.6123535993713838 {'max_features': 8, 'n_estimators': 3}
# 0.5430425641605053 {'max_features': 8, 'n_estimators': 10}
# 0.5218797904248156 {'max_features': 8, 'n_estimators': 30}
# 0.6376003091542167 {'bootstrap': False, 'max_features': 2, 'n_estimators': 3}
# 0.5491371255860421 {'bootstrap': False, 'max_features': 2, 'n_estimators': 10}
# 0.6081369367976419 {'bootstrap': False, 'max_features': 3, 'n_estimators': 3}
# ...

# %%
feature_importances = grid_search.best_estimator_.feature_importances_
>>> feature_importances
# Out:
# array([0.41577777, 0.05159832, 0.07826203, 0.02509771, 0.02224958,
#        0.08963885, 0.11252078, 0.09900811, 0.02408796, 0.05963035,
#        0.02212855])

# %%
final_model = grid_search.best_estimator_

X_test = strat_test_set.drop("MedHouseValue", axis=1)
y_test = strat_test_set["MedHouseValue"].copy()

X_test_prepared = full_pipeline.transform(X_test)

final_predictions = final_model.predict(X_test_prepared)

final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
final_model
final_rmse
# Out:
# 0.5027609752435689

# %%
### In this assignment, I learned the data precosseing, data visualtion, implementation of ML models and how to increase the accuracy of the models
Step 1: Fetching the california Housing Dataset
Step 2: Quick look at the data structure
Step 3: created test Dataset
step 4: data visualization
step 5: determine the correlation coeff
step 6: data preprocessing
step 6: feature scaling( data normalization)
step 7: Select and train the model(Linear regression, DecisionTreeRegressor)
step 8: cross-validation
step 9: Fine tuned the model by using the GridSearchCV
